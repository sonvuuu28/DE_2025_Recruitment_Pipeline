# %%
# from pyspark.sql import SparkSession
# from Cassandra import Cassandra

# spark = (
#     SparkSession.builder.config(
#         "spark.jars.packages", "com.datastax.spark:spark-cassandra-connector_2.12:3.1.0"
#     )
#     .config("spark.cassandra.connection.host", "cassandra_dl")
#     .config("spark.cassandra.connection.port", "9042")
#     .getOrCreate()
# )

# cass = Cassandra(spark)
# data = [{"name": "son", "age": 18}, {"name": "linh", "age": 20}]
# df = spark.createDataFrame(data)   # chuyển list dict -> DataFrame
# cass.insert("test", df)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

df = spark.read.csv("../data/cassandra/tracking.csv", header=True)

# %%
df.show(10)
# Out:
# +--------------------+----+----------+-----------+---+------------+-----+--------------------+---------------+--------------------+-----------------+--------------------+--------------------+------+----+------------+----+---------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+----------+--------+----+--------+
# |         create_time| bid|        bn|campaign_id| cd|custom_track|   de|                  dl|             dt|                  ed|               ev|            group_id|                  id|job_id|  md|publisher_id|  rl|       sr|                  ts|                  tz|                  ua|                 uid|        utm_campaign|         utm_content|         utm_medium|utm_source|utm_term|   v|      vp|
# +--------------------+----+----------+-----------+---+------------+-----+--------------------+---------------+--------------------+-----------------+--------------------+--------------------+------+----+------------+----+---------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+----------+--------+----+--------+
# |f7346e40-0667-11e...|NULL|Chrome 103|       NULL| 24|       click|UTF-8|http://129.213.68...|CandidatePortal|"{""customEvent""...|     ""jobId"":10|   ""publisherId"":0|     ""userId"":78}"|     2|NULL|        NULL|NULL|     true|                NULL|                NULL|           1920x1080|2022-07-18 07:05:...|                -420|Mozilla/5.0 (Maci...|1-d605eqrr-l5m5ugxa|      NULL|    NULL|NULL|    NULL|
# |eccd3a50-018e-11e...|NULL|Chrome 103|       NULL| 24|       click|UTF-8|http://localhost:...|CandidatePortal|"{""customEvent""...|""jobId"":""191""|   ""publisherId"":0|    ""userId"":123}"|     2|NULL|        NULL|NULL|     true|                NULL|http://localhost:...|           1920x1080|2022-07-12 03:01:...|                -420|Mozilla/5.0 (Wind...|1-rrc3k5vd-l4o0b4yy|      NULL|    NULL|NULL|    NULL|
# |a2f155a0-0d60-11e...|   1|Chrome 103|         93| 24|        NULL|UTF-8|http://fe.dev.got...|CandidatePortal|                NULL|                1|                NULL|                NULL|   258|true|           1|NULL| 1366x768|2022-07-27 04:00:...|                -420|Mozilla/5.0 (Wind...| 1-347wwfkr-l632u1zk|                NULL|                NULL|               NULL|      NULL|    NULL|   1|1366x625|
# |a54b7240-0d60-11e...|NULL|Chrome 103|       NULL| 24|       alive|UTF-8|http://fe.dev.got...|CandidatePortal|"{""customEvent""...|""jobId"":""188""|""publisherId"":"...|""stayed_alive"":...|     2|NULL|        NULL|NULL|     true|                NULL|                NULL|            1366x768|2022-07-27 04:00:...|                -420|Mozilla/5.0 (Wind...|1-347wwfkr-l632u1zk|      NULL|    NULL|NULL|    NULL|
# |640f4e30-0c13-11e...|NULL|Chrome 103|       NULL| 24|        NULL|UTF-8|http://fe.stag.go...|CandidatePortal|                NULL|                1|                NULL|                NULL|  NULL|true|        NULL|NULL|1920x1080|2022-07-25 12:14:...|                -420|Mozilla/5.0 (Wind...| 1-vk7kksgd-l5tjg8wn|                NULL|                NULL|               NULL|      NULL|    NULL|   1|1920x947|
# |c9a05e00-0138-11e...|NULL| Chrome 96|       NULL| 24| unqualified|UTF-8|http://150.136.2....|CandidatePortal|"{""customEvent""...|""publisherId"":0|    ""userId"":276}"|                   2|  NULL|NULL|        NULL|true|     NULL|                NULL|           1920x1080|2022-07-11 16:44:...|                -420|Mozilla/5.0 (X11;...| 1-o23lt45w-l516d965|               NULL|      NULL|    NULL|NULL|    NULL|
# |3318e8d0-0bb5-11e...|NULL|Chrome 103|       NULL| 24|        NULL|UTF-8|http://fe.test.go...|CandidatePortal|                NULL|                1|                NULL|                NULL|  NULL|true|        NULL|NULL| 1366x768|2022-07-25 01:00:...|                -420|Mozilla/5.0 (Wind...| 1-rb4yzwxv-l601lrry|                NULL|                NULL|               NULL|      NULL|    NULL|   1|1366x768|
# |f5009130-0d60-11e...|NULL|Chrome 103|       NULL| 24|       alive|UTF-8|http://fe.dev.got...|CandidatePortal|"{""customEvent""...|""jobId"":""258""|""publisherId"":"...|""stayed_alive"":...|     2|NULL|        NULL|NULL|     true|                NULL|                NULL|            1366x768|2022-07-27 04:02:...|                -420|Mozilla/5.0 (Wind...|1-347wwfkr-l632u1zk|      NULL|    NULL|NULL|    NULL|
# |f66ee110-0b59-11e...|   1|Chrome 103|         48| 24|       click|UTF-8|http://fe.dev.got...|CandidatePortal|"{""customEvent""...|""jobId"":""188""|""publisherId"":"...|                   2|    34|NULL|         188|true|        1|                NULL|            1366x768|2022-07-24 14:07:...|                -420|Mozilla/5.0 (Wind...| 1-zof0i457-l5ze6uuv|               NULL|      NULL|    NULL|NULL|    NULL|
# |007515c0-0c00-11e...|   0|Chrome 103|        222| 24|        NULL|UTF-8|http://fe.dev.got...|CandidatePortal|                NULL|                1|                NULL|                NULL|  1530|true|           1|NULL| 1366x768|2022-07-25 09:56:...|                -420|Mozilla/5.0 (Wind...| 1-yh82s4al-l60jlqwa|                NULL|                NULL|               NULL|      NULL|    NULL|   1|1366x568|
# +--------------------+----+----------+-----------+---+------------+-----+--------------------+---------------+--------------------+-----------------+--------------------+--------------------+------+----+------------+----+---------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+----------+--------+----+--------+
# only showing top 10 rows
